# %% [markdown]
# # Step 01: Environment Setup & GPU Verification
#
# This notebook sets up the environment for fine-tuning the **Piper Arabic (`ar_JO`)** TTS model in Google Colab.
#
# ### Pipeline Steps:
# 1. Clone the repository from GitHub
# 2. Verify GPU availability
# 3. Mount Google Drive for state persistence
# 4. Set up Google Drive directory structure (`/content/drive/MyDrive/Arabic-Piper/`)
# 5. Install system packages (`espeak-ng`, system build tools)
# 6. Install Python dependencies from `requirements.txt`

# %%
# 1. Clone Repository from GitHub
# ⚠️ Replace YOUR_USERNAME with your actual GitHub username or org.
import os

REPO_URL = 'https://github.com/YOUR_USERNAME/piper-tts-finetuning.git'  # <-- EDIT THIS
REPO_DIR = '/content/piper-tts-finetuning'

if os.path.exists(REPO_DIR):
    print(f'Repository already cloned at {REPO_DIR}. Pulling latest changes...')
    # !cd {REPO_DIR} && git pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print(f'Working directory: {os.getcwd()}')

# %%
# 2. GPU Check
# !nvidia-smi
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")

# %%
# 3. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 4. Set up Drive Directories
from pathlib import Path

DRIVE_ROOT = Path('/content/drive/MyDrive/Arabic-Piper')
subdirs = ['datasets', 'processed', 'checkpoints', 'tensorboard', 'logs', 'outputs', 'metrics']

for s in subdirs:
    d = DRIVE_ROOT / s
    d.mkdir(parents=True, exist_ok=True)
    print(f"Drive directory verified: {d}")

# %%
# 5. Install System & Python Dependencies
import sys; print(f'Python version: {sys.version}')
# !apt-get update && apt-get install -y espeak-ng libespeak-ng-dev build-essential
# !pip install -r requirements.txt
print('\n✅ All dependencies installed successfully!')
